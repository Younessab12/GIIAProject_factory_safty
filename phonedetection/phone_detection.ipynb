# %%
from ultralytics import YOLO
import cv2
import numpy as np
import cvzone
import math
import mediapipe as mp
import time

# %%
#to work with this projzct ypu need to dowload the model folder from the link below
## https://drive.google.com/drive/folders/1Isyy9n63LzsB0aXEB---i1EtRwG4B521?usp=drive_link ##

model = YOLO('models/best.pt')


caminput =1

# %%
res = model('phone.webp',show=True)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# WARNING  Environment does not support cv2.imshow() or PIL Image.show()
#
# Ultralytics YOLOv8.0.26  Python-3.9.18 torch-2.1.0+cpu CPU
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/1 C:\Users\Dell Latitude 5420\Desktop\IA\GIIAProject_factory_safty\phonedetection\phone.webp: 800x544 1 Dataset - v3 2022-07-05 4-40pm, 193.1ms
# Speed: 8.2ms pre-process, 193.1ms inference, 7.0ms postprocess per image at shape (1, 3, 800, 800)

# %%
cap = cv2.VideoCapture(0)
## phone detection 
while True:
    ret,frame = cap.read()
    frame = cv2.flip(frame,1)
    res = model(frame,stream=True,show=False)
    for r in res:
        boxes = r.boxes
        for box in boxes:
            ## phone index is 67
            clas= int(box.cls[0])
            # if clas != 67:
            #     continue
            x1,y1,x2,y2 = box.xyxy[0]
            x1,y1,x2,y2 = int(x1),int(y1),int(x2),int(y2)
            # cv2.rectangle(frame,(x1,y1),(x2,y2),(0,255,0),2)
            bbox = (x1,y1,x2-x1,y2-y1)
            cvzone.cornerRect(frame,bbox)
            cv2.putText(frame,"phone",(x1,y1-10),cv2.FONT_HERSHEY_COMPLEX,1,(0,255,0),2)
    cv2.imshow('frame',frame)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break
cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 608x800 156.2ms
# Speed: 0.0ms pre-process, 156.2ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 608x800 166.9ms
# Speed: 0.0ms pre-process, 166.9ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 608x800 143.7ms
# Speed: 2.5ms pre-process, 143.7ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 608x800 184.7ms
# Speed: 0.0ms pre-process, 184.7ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 608x800 184.0ms
# Speed: 9.2ms pre-process, 184.0ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 608x800 159.9ms
# Speed: 1.8ms pre-process, 159.9ms inference, 0.5ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 608x800 146.1ms
# Speed: 4.0ms pre-process, 146.1ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 608x800 242.2ms
# Speed: 0.0ms pre-process, 242.2ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 608x800 148.1ms
# Speed: 8.0ms pre-process, 148.1ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 608x800 157.1ms
# Speed: 0.0ms pre-process, 157.1ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 608x800 164.7ms
# Speed: 0.0ms pre-process, 164.7ms inference, 1.2ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 608x800 211.1ms
# Speed: 0.0ms pre-process, 211.1ms inference, 5.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 608x800 196.1ms
# Speed: 0.0ms pre-process, 196.1ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 608x800 156.3ms
# Speed: 0.0ms pre-process, 156.3ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 608x800 149.3ms
# Speed: 0.0ms pre-process, 149.3ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 608x800 174.5ms
# Speed: 0.0ms pre-process, 174.5ms inference, 1.3ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 608x800 166.5ms
# Speed: 0.0ms pre-process, 166.5ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 608x800 151.0ms
# Speed: 8.0ms pre-process, 151.0ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 608x800 151.7ms
# Speed: 0.0ms pre-process, 151.7ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 608x800 150.6ms
# Speed: 0.0ms pre-process, 150.6ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 608x800 169.0ms
# Speed: 0.6ms pre-process, 169.0ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 608x800 157.3ms
# Speed: 0.0ms pre-process, 157.3ms inference, 1.1ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 608x800 145.5ms
# Speed: 0.0ms pre-process, 145.5ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 608x800 151.9ms
# Speed: 0.0ms pre-process, 151.9ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 608x800 149.9ms
# Speed: 0.0ms pre-process, 149.9ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 608x800 170.2ms
# Speed: 0.0ms pre-process, 170.2ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 608x800 168.0ms
# Speed: 0.0ms pre-process, 168.0ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 608x800 152.3ms
# Speed: 0.0ms pre-process, 152.3ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 608x800 179.2ms
# Speed: 5.8ms pre-process, 179.2ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 608x800 166.7ms
# Speed: 0.0ms pre-process, 166.7ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 608x800 163.1ms
# Speed: 0.0ms pre-process, 163.1ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 608x800 183.5ms
# Speed: 8.0ms pre-process, 183.5ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 608x800 219.0ms
# Speed: 0.0ms pre-process, 219.0ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 608x800 234.4ms
# Speed: 0.0ms pre-process, 234.4ms inference, 0.6ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 608x800 173.8ms
# Speed: 0.5ms pre-process, 173.8ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 608x800 164.5ms
# Speed: 0.0ms pre-process, 164.5ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 608x800 157.3ms
# Speed: 0.0ms pre-process, 157.3ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 608x800 162.0ms
# Speed: 0.0ms pre-process, 162.0ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 608x800 178.1ms
# Speed: 0.0ms pre-process, 178.1ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 608x800 171.0ms
# Speed: 0.0ms pre-process, 171.0ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 608x800 228.0ms
# Speed: 0.0ms pre-process, 228.0ms inference, 0.5ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 608x800 178.8ms
# Speed: 1.2ms pre-process, 178.8ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 608x800 179.7ms
# Speed: 0.0ms pre-process, 179.7ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 608x800 166.3ms
# Speed: 4.2ms pre-process, 166.3ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 608x800 177.3ms
# Speed: 0.0ms pre-process, 177.3ms inference, 1.4ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 608x800 171.2ms
# Speed: 1.6ms pre-process, 171.2ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 608x800 186.2ms
# Speed: 0.0ms pre-process, 186.2ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 608x800 1 Dataset - v3 2022-07-05 4-40pm, 214.6ms
# Speed: 1.5ms pre-process, 214.6ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 608x800 181.4ms
# Speed: 5.0ms pre-process, 181.4ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 608x800 161.2ms
# Speed: 0.0ms pre-process, 161.2ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 608x800 163.5ms
# Speed: 0.7ms pre-process, 163.5ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 608x800 165.3ms
# Speed: 0.0ms pre-process, 165.3ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 608x800 173.9ms
# Speed: 0.0ms pre-process, 173.9ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 608x800 163.1ms
# Speed: 0.0ms pre-process, 163.1ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 608x800 153.3ms
# Speed: 8.0ms pre-process, 153.3ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 608x800 177.5ms
# Speed: 0.0ms pre-process, 177.5ms inference, 6.5ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 608x800 183.5ms
# Speed: 0.0ms pre-process, 183.5ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 608x800 1 Dataset - v3 2022-07-05 4-40pm, 171.7ms
# Speed: 0.0ms pre-process, 171.7ms inference, 5.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 608x800 170.9ms
# Speed: 0.0ms pre-process, 170.9ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 608x800 1 Dataset - v3 2022-07-05 4-40pm, 165.4ms
# Speed: 7.1ms pre-process, 165.4ms inference, 8.4ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 608x800 152.5ms
# Speed: 5.8ms pre-process, 152.5ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 608x800 158.2ms
# Speed: 0.0ms pre-process, 158.2ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 608x800 162.6ms
# Speed: 0.0ms pre-process, 162.6ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 608x800 154.4ms
# Speed: 0.0ms pre-process, 154.4ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 608x800 162.8ms
# Speed: 0.0ms pre-process, 162.8ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 608x800 165.5ms
# Speed: 8.0ms pre-process, 165.5ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 608x800 168.0ms
# Speed: 6.5ms pre-process, 168.0ms inference, 0.6ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 608x800 191.5ms
# Speed: 0.0ms pre-process, 191.5ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 608x800 172.2ms
# Speed: 0.0ms pre-process, 172.2ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 608x800 182.2ms
# Speed: 0.0ms pre-process, 182.2ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 608x800 1 Dataset - v3 2022-07-05 4-40pm, 167.3ms
# Speed: 0.0ms pre-process, 167.3ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 608x800 172.7ms
# Speed: 3.8ms pre-process, 172.7ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 608x800 167.0ms
# Speed: 0.0ms pre-process, 167.0ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 608x800 162.8ms
# Speed: 0.0ms pre-process, 162.8ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)

# %%
cap.release()
cv2.destroyAllWindows()

# %%
def phone_detection(frame):
    res = model(frame,stream=True,show=False)
    for r in res:
        for box in r.boxes:
            x1,y1,x2,y2 = box.xyxy[0]
            x1,y1,x2,y2 = int(x1),int(y1),int(x2),int(y2)
            conf = math.ceil(box.conf[0]*100)/100
            return [x1,y1,x2-x1,y2-y1],conf,"phone"
    return None

# %%
cap = cv2.VideoCapture(caminput)
while True:
    ret,frame = cap.read()
    frame = cv2.flip(frame,1)
    bbox = phone_detection(frame)
    if bbox:
        bbox,conf,className = bbox 
        cvzone.cornerRect(frame,bbox)
        cvzone.putTextRect(frame,f'{className} {conf}',(max(0,bbox[0]),max(40,bbox[1]-10)))
    cv2.imshow('frame',frame)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break
cap.release()
cv2.destroyAllWindows()

# %%
from ultralytics import YOLO
import cv2
import numpy as np
import cvzone
import math
import mediapipe as mp
import time
caminput =0

# %%
##mediapipe hand detection
mp_drawing = mp.solutions.drawing_utils
mp_holistic = mp.solutions.holistic
mp_hands = mp.solutions.hands
mp_pose = mp.solutions.pose

# %% [markdown]
# <img src="https://i.imgur.com/qpRACer.png "/>

# %% [markdown]
# <img src="https://camo.githubusercontent.com/7fbec98ddbc1dc4186852d1c29487efd7b1eb820c8b6ef34e113fcde40746be2/68747470733a2f2f6d65646961706970652e6465762f696d616765732f6d6f62696c652f706f73655f747261636b696e675f66756c6c5f626f64795f6c616e646d61726b732e706e67">

# %%
cap = cv2.VideoCapture(caminput)
StartCoords = []
pose = mp.solutions.pose.Pose(model_complexity=2,
    enable_segmentation=True,
    min_detection_confidence=0.5)
hand = mp.solutions.hands.Hands(max_num_hands=2,
    min_detection_confidence=0.5)
prev_time = 0
new_time = 0
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    while cap.isOpened():
        ret, frame = cap.read()
        image = np.zeros(frame.shape, dtype=np.uint8)
        img = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        img = cv2.flip(img, 1)
        img.flags.writeable = False
        res = holistic.process(img)
        pose_res = pose.process(img)
        hand_res = hand.process(img)
        img.flags.writeable = True
        img = cv2.cvtColor(img, cv2.COLOR_RGB2BGR)
        mp_drawing.draw_landmarks(img, res.face_landmarks, mp_holistic.FACEMESH_CONTOURS,
                                  mp_drawing.DrawingSpec(color=(255, 110, 10), thickness=1, circle_radius=1),
                                    mp_drawing.DrawingSpec(color=(255, 256, 121), thickness=1, circle_radius=1)
                                    )
        # if hand_res.multi_hand_landmarks:
        #     for hand_landmarks in hand_res.multi_hand_landmarks:
        #         mp_drawing.draw_landmarks(img, hand_landmarks, mp_hands.HAND_CONNECTIONS)
        mp_drawing.draw_landmarks(img, pose_res.pose_landmarks, mp_pose.POSE_CONNECTIONS,
                          mp_drawing.DrawingSpec(color=(245, 117, 66), thickness=2, circle_radius=4),
                            mp_drawing.DrawingSpec(color=(245, 66, 230), thickness=2, circle_radius=2)
                            )
        if pose_res.pose_landmarks:
            left_hand_end_point = np.array([pose_res.pose_landmarks.landmark[14].x, pose_res.pose_landmarks.landmark[14].y, pose_res.pose_landmarks.landmark[14].z])
            left_hand_start_point = np.array([pose_res.pose_landmarks.landmark[16].x, pose_res.pose_landmarks.landmark[16].y, pose_res.pose_landmarks.landmark[16].z])
            por = 1/9
            Vect_left_hand = (left_hand_end_point - left_hand_start_point)*por + left_hand_start_point
            cv2.circle(img, (int(Vect_left_hand[0]*img.shape[1]), int(Vect_left_hand[1]*img.shape[0])), 5, (0, 0, 255), -1)
            right_hand_end_point = np.array([pose_res.pose_landmarks.landmark[13].x, pose_res.pose_landmarks.landmark[13].y, pose_res.pose_landmarks.landmark[13].z])
            right_hand_start_point = np.array([pose_res.pose_landmarks.landmark[15].x, pose_res.pose_landmarks.landmark[15].y, pose_res.pose_landmarks.landmark[15].z])
            Vect_right_hand = (right_hand_end_point - right_hand_start_point)*por + right_hand_start_point
            cv2.circle(img, (int(Vect_right_hand[0]*img.shape[1]), int(Vect_right_hand[1]*img.shape[0])), 5, (0, 0, 255), -1)
        new_time = time.time()
        fps = 1/(new_time-prev_time)
        prev_time = new_time
        cv2.putText(img, str(int(fps)), (10, 70), cv2.FONT_HERSHEY_PLAIN, 3,
                    (255, 0, 255), 3)
        cv2.imshow("pose detection", image)

        cv2.imshow("Hand Tracking", img)
        
        if cv2.waitKey(10) & 0xFF == ord('q'):
            break
cap.release()
cv2.destroyAllWindows()

# %%
cap.release()
cv2.destroyAllWindows()
