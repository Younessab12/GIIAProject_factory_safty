# %%
from ultralytics import YOLO
import cv2
import numpy as np
import cvzone
import math
import mediapipe as mp

# %%
model = YOLO('models/best.pt')
caminput =1

# %%
res = model('phone.webp',show=True)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# WARNING  Environment does not support cv2.imshow() or PIL Image.show()
#
# Ultralytics YOLOv8.0.26  Python-3.9.18 torch-2.1.0+cpu CPU
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/1 C:\Users\Dell Latitude 5420\Desktop\IA\GIIAProject_factory_safty\phonedetection\phone.webp: 800x544 1 Dataset - v3 2022-07-05 4-40pm, 184.2ms
# Speed: 0.0ms pre-process, 184.2ms inference, 11.0ms postprocess per image at shape (1, 3, 800, 800)

# %%
cap = cv2.VideoCapture(caminput)
## phone detection 
while True:
    ret,frame = cap.read()
    frame = cv2.flip(frame,1)
    res = model(frame,stream=True,show=False)
    for r in res:
        boxes = r.boxes
        for box in boxes:
            ## phone index is 67
            clas= int(box.cls[0])
            # if clas != 67:
            #     continue
            x1,y1,x2,y2 = box.xyxy[0]
            x1,y1,x2,y2 = int(x1),int(y1),int(x2),int(y2)
            # cv2.rectangle(frame,(x1,y1),(x2,y2),(0,255,0),2)
            bbox = (x1,y1,x2-x1,y2-y1)
            cvzone.cornerRect(frame,bbox)
            cv2.putText(frame,"phone",(x1,y1-10),cv2.FONT_HERSHEY_COMPLEX,1,(0,255,0),2)
    cv2.imshow('frame',frame)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break
cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 608x800 1 Dataset - v3 2022-07-05 4-40pm, 178.3ms
# Speed: 12.8ms pre-process, 178.3ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 608x800 149.6ms
# Speed: 0.0ms pre-process, 149.6ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 608x800 143.5ms
# Speed: 0.0ms pre-process, 143.5ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 608x800 194.0ms
# Speed: 0.0ms pre-process, 194.0ms inference, 4.9ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 608x800 185.5ms
# Speed: 3.7ms pre-process, 185.5ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 608x800 177.9ms
# Speed: 1.7ms pre-process, 177.9ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 608x800 166.1ms
# Speed: 0.0ms pre-process, 166.1ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 608x800 1 Dataset - v3 2022-07-05 4-40pm, 196.5ms
# Speed: 8.0ms pre-process, 196.5ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 608x800 1 Dataset - v3 2022-07-05 4-40pm, 139.4ms
# Speed: 7.2ms pre-process, 139.4ms inference, 16.6ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 608x800 1 Dataset - v3 2022-07-05 4-40pm, 138.2ms
# Speed: 0.0ms pre-process, 138.2ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 608x800 141.7ms
# Speed: 1.7ms pre-process, 141.7ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 608x800 1 Dataset - v3 2022-07-05 4-40pm, 143.5ms
# Speed: 0.0ms pre-process, 143.5ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 608x800 1 Dataset - v3 2022-07-05 4-40pm, 166.0ms
# Speed: 0.0ms pre-process, 166.0ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 608x800 1 Dataset - v3 2022-07-05 4-40pm, 144.2ms
# Speed: 0.0ms pre-process, 144.2ms inference, 0.5ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 608x800 1 Dataset - v3 2022-07-05 4-40pm, 143.8ms
# Speed: 0.0ms pre-process, 143.8ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 608x800 1 Dataset - v3 2022-07-05 4-40pm, 152.6ms
# Speed: 0.0ms pre-process, 152.6ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 608x800 1 Dataset - v3 2022-07-05 4-40pm, 268.6ms
# Speed: 0.0ms pre-process, 268.6ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 608x800 1 Dataset - v3 2022-07-05 4-40pm, 140.7ms
# Speed: 0.0ms pre-process, 140.7ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 608x800 137.1ms
# Speed: 0.0ms pre-process, 137.1ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 608x800 1 Dataset - v3 2022-07-05 4-40pm, 139.1ms
# Speed: 0.0ms pre-process, 139.1ms inference, 7.7ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 608x800 1 Dataset - v3 2022-07-05 4-40pm, 165.9ms
# Speed: 0.0ms pre-process, 165.9ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 608x800 1 Dataset - v3 2022-07-05 4-40pm, 177.1ms
# Speed: 0.0ms pre-process, 177.1ms inference, 5.4ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 608x800 1 Dataset - v3 2022-07-05 4-40pm, 169.6ms
# Speed: 0.0ms pre-process, 169.6ms inference, 7.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 608x800 1 Dataset - v3 2022-07-05 4-40pm, 141.9ms
# Speed: 4.9ms pre-process, 141.9ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 608x800 1 Dataset - v3 2022-07-05 4-40pm, 150.2ms
# Speed: 0.0ms pre-process, 150.2ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 608x800 170.4ms
# Speed: 0.0ms pre-process, 170.4ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 608x800 1 Dataset - v3 2022-07-05 4-40pm, 152.4ms
# Speed: 0.0ms pre-process, 152.4ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 608x800 1 Dataset - v3 2022-07-05 4-40pm, 145.8ms
# Speed: 0.0ms pre-process, 145.8ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 608x800 1 Dataset - v3 2022-07-05 4-40pm, 145.5ms
# Speed: 2.7ms pre-process, 145.5ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 608x800 1 Dataset - v3 2022-07-05 4-40pm, 161.6ms
# Speed: 0.0ms pre-process, 161.6ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 608x800 1 Dataset - v3 2022-07-05 4-40pm, 145.6ms
# Speed: 0.0ms pre-process, 145.6ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 608x800 1 Dataset - v3 2022-07-05 4-40pm, 162.5ms
# Speed: 0.0ms pre-process, 162.5ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 608x800 1 Dataset - v3 2022-07-05 4-40pm,
5ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 608x800 148.4ms
# Speed: 0.0ms pre-process, 148.4ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 608x800 1 Dataset - v3 2022-07-05 4-40pm, 142.4ms
# Speed: 0.0ms pre-process, 142.4ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 608x800 160.3ms
# Speed: 0.0ms pre-process, 160.3ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 608x800 159.8ms
# Speed: 0.0ms pre-process, 159.8ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 608x800 157.0ms
# Speed: 0.0ms pre-process, 157.0ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 608x800 148.5ms
# Speed: 5.1ms pre-process, 148.5ms inference, 1.3ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 608x800 1 Dataset - v3 2022-07-05 4-40pm, 184.3ms
# Speed: 0.0ms pre-process, 184.3ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 608x800 208.1ms
# Speed: 5.5ms pre-process, 208.1ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 608x800 151.6ms
# Speed: 0.0ms pre-process, 151.6ms inference, 7.1ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 608x800 148.1ms
# Speed: 0.0ms pre-process, 148.1ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 608x800 141.1ms
# Speed: 0.0ms pre-process, 141.1ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 608x800 137.2ms
# Speed: 0.0ms pre-process, 137.2ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 608x800 151.3ms
# Speed: 0.0ms pre-process, 151.3ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 608x800 1 Dataset - v3 2022-07-05 4-40pm, 143.0ms
# Speed: 0.0ms pre-process, 143.0ms inference, 9.5ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 608x800 176.9ms
# Speed: 0.0ms pre-process, 176.9ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 608x800 156.0ms
# Speed: 4.5ms pre-process, 156.0ms inference, 0.6ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 608x800 139.0ms
# Speed: 0.0ms pre-process, 139.0ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 608x800 146.7ms
# Speed: 0.0ms pre-process, 146.7ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 608x800 202.8ms
# Speed: 4.3ms pre-process, 202.8ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 608x800 133.1ms
# Speed: 0.0ms pre-process, 133.1ms inference, 13.7ms postprocess per image at shape (1, 3, 800, 800)

# %%
cap.release()
cv2.destroyAllWindows()

# %%
def phone_detection(frame):
    res = model(frame,stream=True,show=False)
    for r in res:
        for box in r.boxes:
            x1,y1,x2,y2 = box.xyxy[0]
            x1,y1,x2,y2 = int(x1),int(y1),int(x2),int(y2)
            conf = math.ceil(box.conf[0]*100)/100
            return [x1,y1,x2-x1,y2-y1],conf,"phone"
    return None

# %%
cap = cv2.VideoCapture(caminput)
while True:
    ret,frame = cap.read()
    frame = cv2.flip(frame,1)
    bbox = phone_detection(frame)
    if bbox:
        bbox,conf,className = bbox 
        cvzone.cornerRect(frame,bbox)
        cvzone.putTextRect(frame,f'{className} {conf}',(max(0,bbox[0]),max(40,bbox[1]-10)))
    cv2.imshow('frame',frame)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break
cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 608x800 151.9ms
# Speed: 0.0ms pre-process, 151.9ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 0: 608x800 188.5ms
# Speed: 0.0ms pre-process, 188.5ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 608x800 180.5ms
# Speed: 0.0ms pre-process, 180.5ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 608x800 181.5ms
# Speed: 4.5ms pre-process, 181.5ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 608x800 180.4ms
# Speed: 1.5ms pre-process, 180.4ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 608x800 188.5ms
# Speed: 0.0ms pre-process, 188.5ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 608x800 185.4ms
# Speed: 0.0ms pre-process, 185.4ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 608x800 176.6ms
# Speed: 5.4ms pre-process, 176.6ms inference, 1.7ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 608x800 192.7ms
# Speed: 0.0ms pre-process, 192.7ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 608x800 172.6ms
# Speed: 0.0ms pre-process, 172.6ms inference, 3.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 608x800 182.7ms
# Speed: 0.0ms pre-process, 182.7ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 608x800 198.4ms
# Speed: 0.0ms pre-process, 198.4ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 608x800 188.3ms
# Speed: 7.2ms pre-process, 188.3ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 608x800 169.7ms
# Speed: 8.4ms pre-process, 169.7ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 608x800 182.8ms
# Speed: 0.0ms pre-process, 182.8ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 608x800 180.0ms
# Speed: 0.0ms pre-process, 180.0ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 608x800 151.3ms
# Speed: 6.8ms pre-process, 151.3ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 608x800 174.1ms
# Speed: 0.0ms pre-process, 174.1ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 608x800 161.9ms
# Speed: 0.0ms pre-process, 161.9ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 608x800 179.5ms
# Speed: 0.0ms pre-process, 179.5ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 608x800 175.8ms
# Speed: 0.0ms pre-process, 175.8ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 608x800 167.8ms
# Speed: 5.2ms pre-process, 167.8ms inference, 1.4ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 608x800
6ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 608x800 168.0ms
# Speed: 0.0ms pre-process, 168.0ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 608x800 173.3ms
# Speed: 0.0ms pre-process, 173.3ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 608x800 158.9ms
# Speed: 6.9ms pre-process, 158.9ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 608x800 163.6ms
# Speed: 0.0ms pre-process, 163.6ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 608x800 156.2ms
# Speed: 0.0ms pre-process, 156.2ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 608x800 155.9ms
# Speed: 0.0ms pre-process, 155.9ms inference, 1.1ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 608x800 151.1ms
# Speed: 0.4ms pre-process, 151.1ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 608x800 164.2ms
# Speed: 0.0ms pre-process, 164.2ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 608x800 160.2ms
# Speed: 0.0ms pre-process, 160.2ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 608x800 164.2ms
# Speed: 0.0ms pre-process, 164.2ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 608x800 160.1ms
# Speed: 0.0ms pre-process, 160.1ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 608x800 155.9ms
# Speed: 0.0ms pre-process, 155.9ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 608x800 163.2ms
# Speed: 0.0ms pre-process, 163.2ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 608x800 151.0ms
# Speed: 0.0ms pre-process, 151.0ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 608x800 149.7ms
# Speed: 0.0ms pre-process, 149.7ms inference, 13.0ms postprocess per image at shape (1, 3, 800, 800)
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 0: 608x800 162.0ms
# Speed: 0.0ms pre-process, 162.0ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 608x800 167.0ms
# Speed: 0.0ms pre-process, 167.0ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 608x800 196.3ms
# Speed: 0.0ms pre-process, 196.3ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 608x800 168.3ms
# Speed: 0.0ms pre-process, 168.3ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 608x800 168.9ms
# Speed: 0.0ms pre-process, 168.9ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 608x800 155.5ms
# Speed: 0.0ms pre-process, 155.5ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 608x800 148.5ms
# Speed: 0.0ms pre-process, 148.5ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
#
#
#
#
#
#
#
#
#
#
#
# 0: 608x800 166.7ms
# Speed: 0.0ms pre-process, 166.7ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
#
#
# 0: 608x800 176.3ms
# Speed: 7.5ms pre-process, 176.3ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 608x800 150.6ms
# Speed: 0.0ms pre-process, 150.6ms inference, 14.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 608x800 159.9ms
# Speed: 0.0ms pre-process, 159.9ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 608x800 161.1ms
# Speed: 0.5ms pre-process, 161.1ms inference, 5.5ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 608x800 174.0ms
# Speed: 0.0ms pre-process, 174.0ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 608x800 167.5ms
# Speed: 5.5ms pre-process, 167.5ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 608x800 166.0ms
# Speed: 0.0ms pre-process, 166.0ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 608x800 167.5ms
# Speed: 6.9ms pre-process, 167.5ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 608x800 157.7ms
# Speed: 0.0ms pre-process, 157.7ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 608x800 161.6ms
# Speed: 0.0ms pre-process, 161.6ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 608x800 166.9ms
# Speed: 0.0ms pre-process, 166.9ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)

# %%
##mediapipe hand detection
mp_drawing = mp.solutions.drawing_utils
mp_holistic = mp.solutions.holistic

# %% [markdown]
# <img src="https://i.imgur.com/qpRACer.png "/>

# %% [markdown]
# <img src="https://camo.githubusercontent.com/7fbec98ddbc1dc4186852d1c29487efd7b1eb820c8b6ef34e113fcde40746be2/68747470733a2f2f6d65646961706970652e6465762f696d616765732f6d6f62696c652f706f73655f747261636b696e675f66756c6c5f626f64795f6c616e646d61726b732e706e67">

# %%
cap = cv2.VideoCapture(caminput)
StartCoords = []
pose = mp.solutions.pose.Pose(static_image_mode=True,
    model_complexity=2,
    enable_segmentation=True,
    min_detection_confidence=0.5)

with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    while cap.isOpened():
        ret, frame = cap.read()
        img = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        img = cv2.flip(img, 1)
        img.flags.writeable = False
        res = holistic.process(img)
        respose = pose.process(img)
        img.flags.writeable = True
        img = cv2.cvtColor(img, cv2.COLOR_RGB2BGR)
        mp_drawing.draw_landmarks(img, res.face_landmarks, mp_holistic.FACEMESH_CONTOURS,
                                  mp_drawing.DrawingSpec(color=(255, 110, 10), thickness=1, circle_radius=1),
                                    mp_drawing.DrawingSpec(color=(255, 256, 121), thickness=1, circle_radius=1)
                                    )
        mp_drawing.draw_landmarks(img, res.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS)
        mp_drawing.draw_landmarks(img, res.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS)
        mp_drawing.draw_landmarks(img, respose.pose_landmarks, mp_holistic.POSE_CONNECTIONS,
                          mp_drawing.DrawingSpec(color=(245, 117, 66), thickness=2, circle_radius=4),
                            mp_drawing.DrawingSpec(color=(245, 66, 230), thickness=2, circle_radius=2)
                            )
                

        cv2.imshow("Hand Tracking", img)
        
        if cv2.waitKey(10) & 0xFF == ord('q'):
            break
cap.release()
cv2.destroyAllWindows()
