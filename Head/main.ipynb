# %%
import cv2
import mediapipe as mp
from S3DW.S3DW_models import S3DWStack
import numpy as np

# %%
data_payload = "S3DW is loading"

# eel.init("web")

# %%
def my_thread():
    global data_payload


    agent = S3DWStack()
    mp_face_mesh = mp.solutions.face_mesh
    vid = cv2.VideoCapture(0)

    with mp_face_mesh.FaceMesh(
        max_num_faces=1,
        min_detection_confidence=0.70,
        min_tracking_confidence=0.70,
        refine_landmarks=True,
    ) as face_mesh:
        agent.camera_on = True
        while True:
            ret, frame = vid.read()
            if not ret:
                break

            frame.flags.writeable = False
            frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
            results = face_mesh.process(frame)

            frame.flags.writeable = True
            frame = cv2.cvtColor(frame, cv2.COLOR_RGB2BGR)
            face_coords = results.multi_face_landmarks

            if face_coords != None:
                data_payload = agent.show_data(frame, results)
                level, orientation,eyes, inclination =  data_payload.split()
                print(
                    {"level": level,
                    "orientation": orientation,
                    "eyes": eyes,
                    "inclination": inclination}
                )

            cv2.imshow('frame', frame)
                # eel.my_javascript_function(eyes, level, orientation, inclination)
            # eel.sleep(0.2)
            
            k=cv2.waitKey(10)
            if k ==ord("q"):
                break

    vid.release()
    cv2.destroyAllWindows()

my_thread()
# Out:
# c:\Users\Amine\anaconda3\envs\giia\lib\site-packages\sklearn\base.py:329: UserWarning: Trying to unpickle estimator SVC from version 0.23.2 when using version 1.1.3. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# Model Loaded models/head_pos.sav
# Model Loaded models/orientation.h5
# Model Loaded models/eyescnnoptMehdi1.h5
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 143ms/step
# 1/1 [==============================] - 0s 27ms/step
# {'level': 'Down', 'orientation': 'Center', 'eyes': 'Opened', 'inclination': '88.12'}
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 31ms/step
# {'level': 'Down', 'orientation': 'Center', 'eyes': 'Opened', 'inclination': '87.82'}
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 34ms/step
# {'level': 'Down', 'orientation': 'Center', 'eyes': 'Opened', 'inclination': '87.57'}
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# {'level': 'Down', 'orientation': 'Center', 'eyes': 'Opened', 'inclination': '87.27'}
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 38ms/step
# {'level': 'Down', 'orientation': 'Left', 'eyes': 'Opened', 'inclination': '89.73'}
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 28ms/step
# {'level': 'Front', 'orientation': 'Left', 'eyes': 'Opened', 'inclination': '88.36'}
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 21ms/step
# {'level': 'Front', 'orientation': 'Left', 'eyes': 'Opened', 'inclination': '88.34'}
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# {'level': 'Front', 'orientation': 'Left', 'eyes': 'Closed', 'inclination': '88.87'}
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 33ms/step
# {'level': 'Front', 'orientation': 'Left', 'eyes': 'Opened', 'inclination': '88.00'}
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# {'level': 'Front', 'orientation': 'Left', 'eyes': 'Opened', 'inclination': '89.13'}
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 21ms/step
# {'level': 'Front', 'orientation': 'Left', 'eyes': 'Opened', 'inclination': '88.25'}
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 31ms/step
# {'level': 'Front', 'orientation': 'Left', 'eyes': 'Opened', 'inclination': '89.41'}
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 18ms/step
# {'level': 'Front', 'orientation': 'Left', 'eyes': 'Opened', 'inclination': '89.41'}
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 24ms/step
# {'level': 'Front', 'orientation': 'Left', 'eyes': 'Closed', 'inclination': '88.82'}
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 21ms/step
# {'level': 'Front', 'orientation': 'Center', 'eyes': 'Opened', 'inclination': '88.26'}
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 21ms/step
# {'level': 'Front', 'orientation': 'Center', 'eyes': 'Opened', 'inclination': '88.55'}
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# {'level': 'Front', 'orientation': 'Left', 'eyes': 'Closed', 'inclination': '90.00'}
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# {'level': 'Front', 'orientation': 'Left', 'eyes': 'Closed', 'inclination': '87.32'}
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# {'level': 'Front', 'orientation': 'Left', 'eyes': 'Closed', 'inclination': '87.60'}
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 32ms/step
# {'level': 'Front', 'orientation': 'Left', 'eyes': 'Closed', 'inclination': '87.30'}
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 24ms/step
# {'level': 'Front', 'orientation': 'Center', 'eyes': 'Opened', 'inclination': '88.52'}
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# {'level': 'Front', 'orientation': 'Center', 'eyes': 'Opened', 'inclination': '89.70'}
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 26ms/step
# {'level': 'Front', 'orientation': 'Center', 'eyes': 'Opened', 'inclination': '88.51'}
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 24ms/step
# {'level': 'Front', 'orientation': 'Center', 'eyes': 'Opened', 'inclination': '86.74'}
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 23ms/step
# {'level': 'Front', 'orientation': 'Center', 'eyes': 'Opened', 'inclination': '85.87'}
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 22ms/step
# {'level': 'Front', 'orientation': 'Center', 'eyes': 'Opened', 'inclination': '85.94'}
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 32ms/step
# {'level': 'Front', 'orientation': 'Center', 'eyes': 'Opened', 'inclination': '86.26'}
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 34ms/step
# {'level': 'Front', 'orientation': 'Center', 'eyes': 'Opened', 'inclination': '84.23'}
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 29ms/step
# {'level': 'Front', 'orientation': 'Center', 'eyes': 'Opened', 'inclination': '84.86'}
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 33ms/step
# {'level': 'Front', 'orientation': 'Center', 'eyes': 'Opened', 'inclination': '84.32'}
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 16ms/step
# {'level': 'Front', 'orientation': 'Center', 'eyes': 'Opened', 'inclination': '84.86'}
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 25ms/step
# {'level': 'Front', 'orientation': 'Center', 'eyes': 'Opened', 'inclination': '84.29'}
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 29ms/step
# {'level': 'Down', 'orientation': 'Center', 'eyes': 'Closed', 'inclination': '84.26'}
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# {'level': 'Front', 'orientation': 'Center', 'eyes': 'Closed', 'inclination': '82.77'}
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 22ms/step
# {'level': 'Front', 'orientation': 'Center', 'eyes': 'Opened', 'inclination': '83.44'}
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# {'level': 'Down', 'orientation': 'Center', 'eyes': 'Opened', 'inclination': '82.91'}
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 20ms/step
# {'level': 'Front', 'orientation': 'Center', 'eyes': 'Opened', 'inclination': '84.40'}
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 30ms/step
# {'level': 'Down', 'orientation': 'Center', 'eyes': 'Opened', 'inclination': '84.37'}
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# {'level': 'Down', 'orientation': 'Center', 'eyes': 'Opened', 'inclination': '85.47'}
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 20ms/step
# {'level': 'Front', 'orientation': 'Center', 'eyes': 'Opened', 'inclination': '85.45'}
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 25ms/step
# {'level': 'Front', 'orientation': 'Center', 'eyes': 'Opened', 'inclination': '86.02'}
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# {'level': 'Front', 'orientation': 'Center', 'eyes': 'Opened', 'inclination': '88.26'}
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# {'level': 'Front', 'orientation': 'Center', 'eyes': 'Opened', 'inclination': '88.82'}
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 21ms/step
# {'level': 'Front', 'orientation': 'Center', 'eyes': 'Opened', 'inclination': '89.41'}
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 18ms/step
# {'level': 'Front', 'orientation': 'Left', 'eyes': 'Closed', 'inclination': '87.88'}
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 26ms/step
# {'level': 'Front', 'orientation': 'Left', 'eyes': 'Closed', 'inclination': '86.29'}
